# %% [markdown]
# # https://adventofcode.com/2022

# %%
from pathlib import Path

# %%
puzz = (
    """
Blueprint 1:
  Each ore robot costs 4 ore.
  Each clay robot costs 2 ore.
  Each obsidian robot costs 3 ore and 14 clay.
  Each geode robot costs 2 ore and 7 obsidian.

Blueprint 2:
  Each ore robot costs 2 ore.
  Each clay robot costs 3 ore.
  Each obsidian robot costs 3 ore and 8 clay.
  Each geode robot costs 3 ore and 12 obsidian.
""".replace(
        "\n  ", " "
    )
    .replace("\n\n", "\n")
    .strip("\n")
    .split("\n")
)
# puzz = Path("./day19.txt").read_text().splitlines()

# %%
puzz
# Out:
# ['Blueprint 1: Each ore robot costs 4 ore. Each clay robot costs 2 ore. Each obsidian robot costs 3 ore and 14 clay. Each geode robot costs 2 ore and 7 obsidian.',
#  'Blueprint 2: Each ore robot costs 2 ore. Each clay robot costs 3 ore. Each obsidian robot costs 3 ore and 8 clay. Each geode robot costs 3 ore and 12 obsidian.']

# %% [markdown]
# ## Part 1

# %%
raubaps = dict()

for p in puzz:
    ws = p.split(" ")
    bp = int(ws[1][:-1])
    ore = int(ws[6])
    cla = int(ws[12])
    obs = (int(ws[18]), int(ws[21]))
    geo = (int(ws[27]), int(ws[30]))
    raubaps[bp] = dict(ore=ore, cla=cla, obs=obs, geo=geo)

# %%
memo = dict()

for bp, bpraubap in raubaps.items():
    bp, bpraubap

# %%
memo[bp] = dict()

state = (24, (1, 0), (0, 0), (0, 0), (0, 0))


def recu(tuns: int, ore: tuple, cla: tuple, obs: tuple, geo: tuple, bpraubap=dict):
    return


recu(*state, bpraubap)

# %%
tuns, (orerau, oreres), (clarau, clares), (obsrau, obsres), (georau, geores) = state

# %%
if bpraubap['ore'] oreres:
    recu

if bpraubap['ore']

# %%
bpraubap
# Out:
# {'ore': 2, 'cla': 3, 'obs': (3, 8), 'geo': (3, 12)}

# %%
raubap
# Out:
# {'ore': 2, 'cla': 3, 'obs': (3, 8), 'geo': (3, 12)}

# %% [markdown]
# ## Part 2
