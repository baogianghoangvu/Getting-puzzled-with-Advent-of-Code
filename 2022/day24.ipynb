# %% [markdown]
# # https://adventofcode.com/2022

# %%
from pathlib import Path

# %%
puzz = """
#.######
#>>.<^<#
#.<..<<#
#>v.><>#
#<^v^^>#
######.#
""".strip(
    "\n"
).split(
    "\n"
)
# puzz = Path("./day24.txt").read_text().splitlines()

# %%
puzz[:5]
# Out:
# ['#.######', '#>>.<^<#', '#.<..<<#', '#>v.><>#', '#<^v^^>#']

# %% [markdown]
# ## Part 1

# %%
for line in puzz:
    print(line)
# Out:
# #.######
# #>>.<^<#
# #.<..<<#
# #>v.><>#
# #<^v^^>#
# ######.#

# %% [markdown]
# ## Part 2
