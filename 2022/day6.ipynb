# %% [markdown]
# # https://adventofcode.com/2022

# %%
import string
from pathlib import Path

# %%
puzz = Path("./day6.txt").read_text().splitlines()[0]

# %% [markdown]
# ## Part 1

# %%
length = 4

for i in range(len(puzz) - length + 1):
    if len(set(puzz[i : i + length])) == length:
        break
i + length
# Out:
# 1702

# %% [markdown]
# ## Part 2

# %%
length = 14

for i in range(len(puzz) - length + 1):
    if len(set(puzz[i : i + length])) == length:
        break
i + length
# Out:
# 3559
