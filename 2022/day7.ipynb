# %% [markdown]
# # https://adventofcode.com/2022

# %%
import string
from pathlib import Path

# %%
puzz = """
$ cd /
$ ls
dir a
14848514 b.txt
8504156 c.dat
dir d
$ cd a
$ ls
dir e
29116 f
2557 g
62596 h.lst
$ cd e
$ ls
584 i
$ cd ..
$ cd ..
$ cd d
$ ls
4060174 j
8033020 d.log
5626152 d.ext
7214296 k
""".strip().split(
    "\n"
)

puzz = Path("./day7.txt").read_text().splitlines()

# %% [markdown]
# ## Part 1

# %%
dirs = {}
d = Path("/")
for l in puzz:
    if l.startswith("$ cd"):
        if l[5:] == "..":
            file_size = sum(dirs[d]["file"])
            subd_size = sum(dirs[s]["size"] for s in dirs[d]["subd"])
            dirs[d]["size"] = file_size + subd_size
            d = d.parent
        else:
            d = d / l[5:]
            dirs[d] = {
                "file": [],
                "subd": [],
                "size": 0,
            }
    elif l == "$ ls":
        pass
    else:
        if l.startswith("dir "):
            dirs[d]["subd"].append(d / l[4:])
        else:
            dirs[d]["file"].append(int(l.split(" ")[0]))

while True:
    print(d)
    file_size = sum(dirs[d]["file"])
    subd_size = sum(dirs[s]["size"] for s in dirs[d]["subd"])
    dirs[d]["size"] = file_size + subd_size
    if d == d.parent:
        break
    d = d.parent
# Out:
# \rvvjbz\jqlm
# \rvvjbz
# \

# %%
sum(v["size"] for v in dirs.values() if v["size"] <= 1e5)
# Out:
# 1391690

# %% [markdown]
# ## Part 2

# %%
total = 70000000
updat = 30000000
curre = dirs[Path("/")]["size"]
tofre = curre - (total - updat)
tofre
# Out:
# 4795677

# %%
min([v["size"] for v in dirs.values() if v["size"] >= tofre])
# Out:
# 5469168
