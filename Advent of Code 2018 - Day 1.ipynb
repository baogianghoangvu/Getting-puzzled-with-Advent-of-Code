# %% [markdown]
# https://adventofcode.com/2018/day/1

# %%
import numpy as np

# %%
# Use code_prettify notebook_extension to tidy the list
freq_change_list = np.array([
    -7, -19, +18, +19, -10, -12, -19, -9, -15, -4, -2, +9, -1, -3, +15, +18,
    -5, -19, +3, -13, +14, -7, -10, -17, +14, -4, +1, -16, -1, -2, +15, -9, +4,
    -9, -3, -2, -8, -3, -10, +19, -18, -4, +5, -11, +15, -14, -20, -14, -8, +2,
    -6, -10, -13, +9, -13, -12, +17, +7, +18, -7, +13, +2, +2, -5, -6, -15,
    +11, -18, -9, +13, -8, -17, -5, +16, -10, +7, +7, +7, -15, -9, +5, +10, -9,
    -18, -16, +17, -19, -13, +17, -1, -19, -5, +10, -13, +9, -14, -6, +13, -10,
    -4, -2, -17, +14, +2, -4, +9, +16, +9, +5, +19, +1, -11, +17, -16, +3, -2,
    +3, +1, -19, +2, -1, +20, +13, -18, +17, +4, +19, +13, +6, +13, +10, -2,
    -10, +16, +4, -6, -9, +10, +18, -5, -4, -11, +13, -15, +12, +12, +17, +11,
    -19, -5, +14, -21, -15, +5, +7, +7, -2, -9, +5, -11, +12, +14, -3, -15,
    +33, +5, +16, +9, -5, -16, +9, -11, +12, +12, +10, +12, +16, -15, -3, -6,
    -18, +1, -17, +23, +23, +5, +16, +15, +3, +16, +19, -6, +10, -6, +8, -18,
    +14, +14, +8, +16, -11, -15, -2, +16, -13, -10, +14, -2, +16, +16, +4, -11,
    +2, +12, +18, +18, +3, -10, -16, -2, +13, -10, +16, -14, +18, -11, +12,
    +17, +19, +9, -19, -3, -10, +2, -7, +16, +16, -12, +10, -1, +10, +11, +1,
    -11, -6, +13, +6, -10, -7, +12, -2, +12, -6, +15, +17, -4, -3, -12, +7,
    -11, +22, -9, +14, -2, -5, -6, -15, +3, -7, -1, +11, +4, -8, +20, +5, +17,
    -7, -19, -5, -4, +7, +20, +5, -3, +1, +20, +14, +14, +1, +16, +10, -7, +24,
    +11, +4, -14, -5, +18, +7, +12, -8, -2, +23, -19, +48, +10, +13, +5, -10,
    +2, -1, +26, +12, +13, +25, -12, +13, +3, -2, +13, +4, +5, +13, -6, -4,
    -16, +19, +8, +19, +4, -7, +1, -14, +8, -7, -20, -9, +19, +1, +17, +18,
    +16, -19, +4, +20, +5, +24, +18, -1, +23, +16, +8, +8, -21, -14, -16, -8,
    +11, +5, +4, -18, -20, -10, +18, -15, -1, +5, -11, -7, +5, -18, +2, +4, +3,
    -21, +4, +12, -7, +17, +16, +15, -8, -8, -12, +8, +8, +10, +1, +11, -17,
    +3, -1, -24, -5, -24, -22, +4, +3, +2, -18, -19, -8, +13, +13, +13, -7,
    +19, -14, -2, +37, +21, +14, +11, +3, +17, +8, +2, -4, +15, -4, +18, +7,
    -12, +2, -8, +9, -11, -9, +2, -16, -4, +54, -12, +28, +10, +7, -3, +11,
    +13, -3, +16, -3, +4, +24, -3, +18, +6, +19, +3, +15, +32, +2, +24, -31,
    -90, -17, +23, -21, +14, +16, +9, -32, +5, +16, -44, +26, -20, -9, +22,
    +23, -33, -13, -31, -15, +13, -8, -22, +15, -19, +18, -6, +10, -62, +31,
    -6, -5, +82, +8, +30, +48, +10, -3, +87, +17, +10, -17, -4, +83, +1, -2,
    +5, +9, -19, -10, +33, +19, -17, -21, -51, +24, +26, +17, +2, +19, +50,
    -125, -152, +72082, -9, -15, +19, -16, +2, +15, -11, -16, +19, +10, -4,
    +12, -13, +19, +16, +8, -10, -4, -13, +18, -7, +10, -17, +1, +11, -8, -6,
    +5, +16, +21, -9, -6, +19, -6, -6, -2, -8, +19, -8, +16, +5, -19, +18, +13,
    -16, +13, +8, -16, +9, +15, +9, -19, +16, -18, +19, +15, +10, -17, -2, +13,
    +4, -5, +17, +2, +6, +9, -5, -3, +18, -11, -17, +7, +9, +18, +1, -16, -11,
    +14, +10, -5, +2, +13, +9, -5, +9, -3, -19, -9, -4, -14, -9, -9, +6, -4,
    +22, +18, -7, +17, +14, +16, -17, -3, -5, -4, -4, -11, +13, -1, +18, +10,
    -6, -11, +13, -15, +18, +12, +3, -1, +7, -18, +8, -4, +3, +15, -19, -12,
    -2, +12, +14, +11, +19, +1, -6, -1, -18, -16, +1, -7, -19, -17, -20, +10,
    +23, +19, -2, -18, +15, +20, +6, +7, +12, +14, +6, -11, -1, -12, -7, +10,
    -17, +11, +4, +9, +10, +9, -7, +18, -6, +14, +9, -19, -12, +16, +21, -10,
    -7, +14, -9, +10, -17, +11, -18, -12, +6, -12, -14, +12, -19, +4, -19, +5,
    +6, +12, +35, +17, +7, +18, +18, -13, -17, +1, -6, +4, -18, -19, +12, +5,
    +17, +10, +13, +14, +11, +16, -12, +19, -5, +14, -3, +6, -11, +16, +18,
    +16, -14, +12, +3, +3, +17, +2, -11, -9, +7, +3, +15, +14, -9, -8, +15, -5,
    +11, -14, -1, +12, +6, -1, -14, +10, +11, -19, -17, -14, -12, +18, -2, -21,
    -10, -8, -18, -20, +1, -12, +18, -10, +11, +17, +6, +9, -4, +12, +12, +7,
    -8, -18, -13, +7, -14, +11, -2, +9, +5, +11, -12, -1, +22, -6, +17, +19,
    -8, -1, -3, +1, +15, -3, +2, -9, -4, -19, -8, +5, -9, -2, -6, -30, -16, -7,
    +11, +3, +7, -9, +10, -19, +10, -17, +3, -5, -14, -18, -2, +16, -13, +6,
    -3, +15, -10, -10, -15, +21, -11, +17, +19, -7, +2, -13, +4, +15, -7, -14,
    -17, -4, -15, -17, -16, +14, +9, +15, -7, -4, -8, -12, +5, -1, -16, -15,
    +11, +29, +20, +6, +16, +19, -5, +11, -1, +12, +9, +9, +13, +13, -4, +14,
    +3, +20, -21, -27, -13, +7, +3, +8, +63, +15, +23, -3, -6, -12, -1, +16,
    -1, +14, -8, -18, +17, +4, -10, +17, +1, +9, -11, -3, -9, +5, +19, -17,
    +12, +14, +5, -17, +22, -18, -7, +28, -19, +22, +25, -2, -8, +6, +5, +21,
    +18, +18, -2, +17, +13, +18, -8, -16, -11, -6, +4, +9, +2, -18, -7, +18,
    -10, +18, +8, +5, -17, +2, -23, +10, +31, +20, -13, -19, -26, -5, -11, -18,
    +15, -19, -2, +19, +12, +14, +8, -25, -18, -23, -19, -11, -6, -11, +13, -4,
    +20, -4, +9, +15, +2, +18, +6, +10, -3, -14, +6, -15, -2, -7, +21, +22, +5,
    +43, -5, +6, +65, +24, +106, -14, +30, -3, -12, -75, -115, +20, -11, +84,
    -17, +135, +67, +13, +37, +62, -73422
])

# %% [markdown]
# # Part 1

# %%
np.cumsum(freq_change_list)[-1]
# Out:
# 518

# %% [markdown]
# # Part 2

# %%
short_freq_change_list = [7,7,-2,-7,-4]  # answer = 14

# %%
# array = short_freq_change_list
array = freq_change_list

historical_freq = []
loop = True
while loop:
    previous_freq = historical_freq[:]
    if not historical_freq:
        historical_freq = list(np.cumsum(array))
    else:
        new_freq = list(np.cumsum(array)+historical_freq[-1])
        historical_freq += new_freq

    if len(historical_freq) != len(set(historical_freq)):  # if dup
        for f in new_freq:
            if not loop:
                break
            if f in previous_freq:
                print(f)
                loop = False
# Out:
# 72889
